# %%
from random import random

# %%
random()
# Out:
# 0.31940341243026216

# %%
darts_x = [(random()) for x in range(1000)]

# %%
darts_x[:10]
# Out:
# [0.09476710401756028,
#  0.04452641280744929,
#  0.8956444785541743,
#  0.027399142676210464,
#  0.42162197612775854,
#  0.8332182345012676,
#  0.07236597874699624,
#  0.38267658370652236,
#  0.5090470537255162,
#  0.7162368477331486]

# %%
len(darts_x)
# Out:
# 1000

# %%
darts_y = [(random()) for x in range(1000)]

# %%
darts_y[:10]
# Out:
# [0.43452168906476774,
#  0.004142097102957543,
#  0.07554226784176299,
#  0.0563677131780308,
#  0.08389096959240472,
#  0.782233835875922,
#  0.949613236252462,
#  0.041592845445510895,
#  0.27259166051873285,
#  0.36602960116829897]

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
_ = plt.plot([darts_x],[darts_y], "ro")

# %%
darts_xy = [(darts_x[i], darts_x[i]) for i in range(len(darts_x))]

# %%
darts_xy[:10]
# Out:
# [(0.09476710401756028, 0.09476710401756028),
#  (0.04452641280744929, 0.04452641280744929),
#  (0.8956444785541743, 0.8956444785541743),
#  (0.027399142676210464, 0.027399142676210464),
#  (0.42162197612775854, 0.42162197612775854),
#  (0.8332182345012676, 0.8332182345012676),
#  (0.07236597874699624, 0.07236597874699624),
#  (0.38267658370652236, 0.38267658370652236),
#  (0.5090470537255162, 0.5090470537255162),
#  (0.7162368477331486, 0.7162368477331486)]

# %%
darts_in_circle = [d for d in darts_xy if d[0]**2+d[1]**2<1]

# %%
darts_in_circle[:10]
# Out:
# [(0.09476710401756028, 0.09476710401756028),
#  (0.04452641280744929, 0.04452641280744929),
#  (0.027399142676210464, 0.027399142676210464),
#  (0.42162197612775854, 0.42162197612775854),
#  (0.07236597874699624, 0.07236597874699624),
#  (0.38267658370652236, 0.38267658370652236),
#  (0.5090470537255162, 0.5090470537255162),
#  (0.6612415682988392, 0.6612415682988392),
#  (0.4928973961548241, 0.4928973961548241),
#  (0.0390717455894386, 0.0390717455894386)]

# %%
darts_in_circle_x = [x[0] for x in darts_in_circle]

# %%
darts_in_circle_x[:10]
# Out:
# [0.09476710401756028,
#  0.04452641280744929,
#  0.027399142676210464,
#  0.42162197612775854,
#  0.07236597874699624,
#  0.38267658370652236,
#  0.5090470537255162,
#  0.6612415682988392,
#  0.4928973961548241,
#  0.0390717455894386]

# %%
darts_in_circle_y = [x[1] for x in darts_in_circle]

# %%
# %matplotlib inline

_ = plt.plot([darts_x],[darts_y], "bo")

_ = plt.plot(darts_in_circle_x, darts_in_circle_y, "ro")
